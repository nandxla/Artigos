# %% [markdown]
# # Summary Tools
# Agora vamos dar um "tchan" no seu describe, trazendo algumas melhorias de visualização com a lib ```summarytools```

# %%
# !pip install summarytools
from summarytools import dfSummary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('all_seasons.csv')

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_f9ae7 thead>tr>th {
#   text-align: left;
# }
# #T_f9ae7_row0_col0, #T_f9ae7_row1_col0, #T_f9ae7_row2_col0, #T_f9ae7_row3_col0, #T_f9ae7_row4_col0, #T_f9ae7_row5_col0, #T_f9ae7_row6_col0, #T_f9ae7_row7_col0, #T_f9ae7_row8_col0, #T_f9ae7_row9_col0, #T_f9ae7_row10_col0, #T_f9ae7_row11_col0, #T_f9ae7_row12_col0, #T_f9ae7_row13_col0, #T_f9ae7_row14_col0, #T_f9ae7_row15_col0, #T_f9ae7_row16_col0, #T_f9ae7_row17_col0, #T_f9ae7_row18_col0, #T_f9ae7_row19_col0, #T_f9ae7_row20_col0, #T_f9ae7_row21_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# ...
